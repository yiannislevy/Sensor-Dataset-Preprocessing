# %%
import numpy as np
import pandas as pd
import os
from scipy import stats, signal
from datetime import timedelta

# %%
sensor_dtype = np.dtype([
    ("x", ">f4"),
    ("y", ">f4"),
    ("z", ">f4"),
    ("time", ">i8"),
])


def load_raw_sensor_data(path):
    """Load and process sensor data from binary files"""
    acc_files = sorted([f for f in os.listdir(path) if f.endswith('.bin') and 'accelerometer' in f])
    gyro_files = sorted([f for f in os.listdir(path) if f.endswith('.bin') and 'gyroscope' in f])

    all_acc_data = []
    all_gyro_data = []

    # Load accelerometer data
    for file in acc_files:
        boot_time_nanos = int(file.split("_")[0]) * 1e6
        file_path = os.path.join(path, file)
        acc_data = np.fromfile(file_path, dtype=sensor_dtype)
        first_event_time = acc_data['time'][0]
        corrected_timestamps = ((acc_data['time'] - first_event_time) + boot_time_nanos) / 1e9
        corrected_datetimes = pd.to_datetime(corrected_timestamps, unit='s')
        df = pd.DataFrame(acc_data[["x", "y", "z"]].byteswap().newbyteorder())
        df['time'] = corrected_datetimes
        all_acc_data.append(df)

    # Load gyroscope data
    for file in gyro_files:
        boot_time_nanos = int(file.split("_")[0]) * 1e6
        file_path = os.path.join(path, file)
        gyro_data = np.fromfile(file_path, dtype=sensor_dtype)
        first_event_time = gyro_data['time'][0]
        corrected_timestamps = ((gyro_data['time'] - first_event_time) + boot_time_nanos) / 1e9
        corrected_datetimes = pd.to_datetime(corrected_timestamps, unit='s')
        df = pd.DataFrame(gyro_data[["x", "y", "z"]].byteswap().newbyteorder())
        df['time'] = corrected_datetimes
        all_gyro_data.append(df)

    return pd.concat(all_acc_data), pd.concat(all_gyro_data)


def sync_sensors(acc_data, gyro_data):
    """Synchronize accelerometer and gyroscope data"""
    common_start_time = max(acc_data['time'].min(), gyro_data['time'].min())
    common_end_time = min(acc_data['time'].max(), gyro_data['time'].max())

    acc_synced = acc_data[(acc_data['time'] >= common_start_time) & (acc_data['time'] <= common_end_time)]
    gyro_synced = gyro_data[(gyro_data['time'] >= common_start_time) & (gyro_data['time'] <= common_end_time)]

    return acc_synced.reset_index(drop=True), gyro_synced.reset_index(drop=True)

# %%
def analyze_session(path):
    """Analyze a single session's IMU data"""
    # Load and sync the data
    acc_data, gyro_data = load_raw_sensor_data(path)
    acc_synced, gyro_synced = sync_sensors(acc_data, gyro_data)
    
    # Calculate session duration
    duration = (acc_synced['time'].max() - acc_synced['time'].min()).total_seconds()
    
    # Calculate temporal characteristics
    time_diffs_acc = acc_synced['time'].diff()[1:].dt.total_seconds()
    time_diffs_gyro = gyro_synced['time'].diff()[1:].dt.total_seconds()
    
    actual_rate_acc = 1 / time_diffs_acc.mean()
    rate_std_acc = np.std(1 / time_diffs_acc)
    
    # Calculate temporal offset between sensors
    temporal_offset = (acc_synced['time'] - gyro_synced['time']).dt.total_seconds() * 1000  # in milliseconds
    
    # Calculate signal characteristics for both sensors
    acc_stats = calculate_signal_stats(acc_synced)
    gyro_stats = calculate_signal_stats(gyro_synced)
    
    # Calculate spectral characteristics
    acc_spectral = calculate_spectral_components(acc_synced)
    gyro_spectral = calculate_spectral_components(gyro_synced)
    
    # Calculate data quality metrics
    expected_samples = int(duration * actual_rate_acc)
    missing_samples_pct = (1 - len(acc_synced) / expected_samples) * 100
    
    # Sample interval confidence
    interval_ci = stats.norm.interval(0.95, 
                                    loc=time_diffs_acc.mean() * 1000,  # convert to ms
                                    scale=time_diffs_acc.std() * 1000)
    
    return {
        'duration_hours': duration / 3600,
        'temporal_chars': {
            'mean_sampling_rate': actual_rate_acc,
            'sampling_rate_std': rate_std_acc,
            'temporal_offset_mean': temporal_offset.mean(),
            'temporal_offset_std': temporal_offset.std()
        },
        'acc_stats': acc_stats,
        'gyro_stats': gyro_stats,
        'acc_spectral': acc_spectral,
        'gyro_spectral': gyro_spectral,
        'data_quality': {
            'missing_samples_pct': missing_samples_pct,
            'timestamp_continuity': (time_diffs_acc < 0.02).mean() * 100,  # % of intervals < 20ms
            'interval_ci': interval_ci
        }
    }

def calculate_signal_stats(data):
    """Calculate comprehensive signal statistics"""
    stats_dict = {}
    for axis in ['x', 'y', 'z']:
        signal_data = data[axis]
        stats_dict[axis] = {
            'range': [signal_data.min(), signal_data.max()],
            'mean': signal_data.mean(),
            'std': signal_data.std(),
            'skewness': stats.skew(signal_data),
            'kurtosis': stats.kurtosis(signal_data),
            'snr': calculate_snr(signal_data)
        }
    return stats_dict

def calculate_snr(signal_data):
    """Calculate Signal-to-Noise Ratio"""
    f, psd = signal.welch(signal_data, fs=100)  # Assuming 100Hz sampling rate
    signal_power = np.sum(psd[f < 10])  # Signal components below 10Hz
    noise_power = np.sum(psd[f >= 10])  # Noise components above 10Hz
    return 10 * np.log10(signal_power / noise_power) if noise_power > 0 else 0

def calculate_spectral_components(data):
    """Calculate spectral components in three frequency bands"""
    spectral_stats = {}
    for axis in ['x', 'y', 'z']:
        f, psd = signal.welch(data[axis], fs=100)
        total_power = np.sum(psd)
        
        # Calculate power in each frequency band
        low_freq = np.sum(psd[(f >= 0.1) & (f < 3)]) / total_power * 100
        mid_freq = np.sum(psd[(f >= 3) & (f < 10)]) / total_power * 100
        high_freq = np.sum(psd[f >= 10]) / total_power * 100
        
        spectral_stats[axis] = {
            'low_freq': low_freq,
            'mid_freq': mid_freq,
            'high_freq': high_freq
        }
    return spectral_stats

def analyze_dataset(base_path):
    """Analyze all sessions in the dataset"""
    session_dirs = [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]
    all_sessions = []
    
    for session_dir in session_dirs:
        session_path = os.path.join(base_path, session_dir)
        session_stats = analyze_session(session_path)
        all_sessions.append(session_stats)
    
    # Calculate dataset-wide statistics
    durations = [s['duration_hours'] for s in all_sessions]
    sampling_rates = [s['temporal_chars']['mean_sampling_rate'] for s in all_sessions]
    
    summary = {
        'total_sessions': len(all_sessions),
        'total_duration': sum(durations),
        'avg_session_duration': np.mean(durations) * 60,  # in minutes
        'session_duration_std': np.std(durations) * 60,  # in minutes
        'avg_sampling_rate': np.mean(sampling_rates),
        'total_samples': sum(int(d * 3600 * r) for d, r in zip(durations, sampling_rates))
    }
    
    return summary, all_sessions

# %%
# Usage
if __name__ == "__main__":
    dataset_path = "../data/raw"
    summary, sessions = analyze_dataset(dataset_path)
    
    print("\nDataset Summary:")
    print(f"Total Sessions: {summary['total_sessions']}")
    print(f"Total Duration: {summary['total_duration']:.1f} hours")
    print(f"Average Session Duration: {summary['avg_session_duration']:.1f} minutes")
    print(f"Session Duration Std: {summary['session_duration_std']:.1f} minutes")
    print(f"Average Sampling Rate: {summary['avg_sampling_rate']:.2f} Hz")
    print(f"Total Samples: {summary['total_samples']:,}")

    print("\nDetailed Signal Statistics:")
    print("\nAccelerometer Statistics:")
    for session_idx, session in enumerate(sessions):
        print(f"\nSession {session_idx + 1}:")
        acc_stats = session['acc_stats']
        for axis in ['x', 'y', 'z']:
            print(f"\n{axis}-axis:")
            print(f"Range: [{acc_stats[axis]['range'][0]:.1f}, {acc_stats[axis]['range'][1]:.1f}] m/s²")
            print(f"Mean: {acc_stats[axis]['mean']:.2f} m/s²")
            print(f"Std: {acc_stats[axis]['std']:.2f}")
            print(f"Skewness: {acc_stats[axis]['skewness']:.2f}")
            print(f"Kurtosis: {acc_stats[axis]['kurtosis']:.2f}")
            print(f"SNR: {acc_stats[axis]['snr']:.1f} dB")

    print("\nGyroscope Statistics:")
    for session_idx, session in enumerate(sessions):
        print(f"\nSession {session_idx + 1}:")
        gyro_stats = session['gyro_stats']
        for axis in ['x', 'y', 'z']:
            print(f"\n{axis}-axis:")
            print(f"Range: [{gyro_stats[axis]['range'][0]:.1f}, {gyro_stats[axis]['range'][1]:.1f}] rad/s")
            print(f"Mean: {gyro_stats[axis]['mean']:.2f} rad/s")
            print(f"Std: {gyro_stats[axis]['std']:.2f}")
            print(f"Skewness: {gyro_stats[axis]['skewness']:.2f}")
            print(f"Kurtosis: {gyro_stats[axis]['kurtosis']:.2f}")
            print(f"SNR: {gyro_stats[axis]['snr']:.1f} dB")

    print("\nSpectral Components:")
    for session_idx, session in enumerate(sessions):
        print(f"\nSession {session_idx + 1}:")
        
        print("\nAccelerometer Spectral Components:")
        for axis in ['x', 'y', 'z']:
            print(f"\nSpectral components for {axis}-axis:")
            print(f"Low-frequency (0.1-3 Hz): {session['acc_spectral'][axis]['low_freq']:.1f}%")
            print(f"Mid-frequency (3-10 Hz): {session['acc_spectral'][axis]['mid_freq']:.1f}%")
            print(f"High-frequency (>10 Hz): {session['acc_spectral'][axis]['high_freq']:.1f}%")
        
        print("\nGyroscope Spectral Components:")
        for axis in ['x', 'y', 'z']:
            print(f"\nSpectral components for {axis}-axis:")
            print(f"Low-frequency (0.1-3 Hz): {session['gyro_spectral'][axis]['low_freq']:.1f}%")
            print(f"Mid-frequency (3-10 Hz): {session['gyro_spectral'][axis]['mid_freq']:.1f}%")
            print(f"High-frequency (>10 Hz): {session['gyro_spectral'][axis]['high_freq']:.1f}%")

    print("\nTemporal Characteristics:")
    for session_idx, session in enumerate(sessions):
        print(f"\nSession {session_idx + 1}:")
        temporal = session['temporal_chars']
        print(f"Mean Sampling Rate: {temporal['mean_sampling_rate']:.2f} Hz")
        print(f"Sampling Rate Std: {temporal['sampling_rate_std']:.2f} Hz")
        print(f"Mean Temporal Offset: {temporal['temporal_offset_mean']:.2f} ms")
        print(f"Temporal Offset Std: {temporal['temporal_offset_std']:.2f} ms")

    print("\nData Quality Metrics:")
    for session_idx, session in enumerate(sessions):
        print(f"\nSession {session_idx + 1}:")
        quality = session['data_quality']
        print(f"Missing Samples: {quality['missing_samples_pct']:.2f}%")
        print(f"Timestamp Continuity: {quality['timestamp_continuity']:.2f}%")
        print(f"Sample Interval 95% CI: [{quality['interval_ci'][0]:.1f}, {quality['interval_ci'][1]:.1f}] ms")
# Out:
# Dataset Summary:
# Total Sessions: 26
# Total Duration: 9.6 hours
# Average Session Duration: 22.2 minutes
# Session Duration Std: 10.9 minutes
# Average Sampling Rate: 51.84 Hz
# Total Samples: 1,800,366
#
# Detailed Signal Statistics:
#
# Accelerometer Statistics:
#
# Session 1:
#
# x-axis:
# Range: [-17.7, 36.4] m/s²
# Mean: 0.07 m/s²
# Std: 4.51
# Skewness: 0.45
# Kurtosis: -0.66
# SNR: 12.9 dB
#
# y-axis:
# Range: [-44.2, 13.9] m/s²
# Mean: -7.18 m/s²
# Std: 2.89
# Skewness: 0.74
# Kurtosis: 4.63
# SNR: 9.2 dB
#
# z-axis:
# Range: [-14.7, 34.2] m/s²
# Mean: 2.22 m/s²
# Std: 4.23
# Skewness: -0.03
# Kurtosis: -0.27
# SNR: 12.8 dB
#
# Session 2:
#
# x-axis:
# Range: [-36.1, 16.9] m/s²
# Mean: -1.15 m/s²
# Std: 6.33
# Skewness: -0.34
# Kurtosis: -0.61
# SNR: 14.8 dB
#
# y-axis:
# Range: [-49.1, 35.8] m/s²
# Mean: -5.39 m/s²
# Std: 3.90
# Skewness: 0.12
# Kurtosis: 0.28
# SNR: 9.1 dB
#
# z-axis:
# Range: [-21.6, 25.7] m/s²
# Mean: 2.74 m/s²
# Std: 3.79
# Skewness: -0.18
# Kurtosis: 0.20
# SNR: 12.3 dB
#
# Session 3:
#
# x-axis:
# Range: [-10.8, 20.1] m/s²
# Mean: 0.05 m/s²
# Std: 4.75
# Skewness: 0.76
# Kurtosis: -0.23
# SNR: 17.4 dB
#
# y-axis:
# Range: [-23.1, 9.0] m/s²
# Mean: -7.75 m/s²
# Std: 2.93
# Skewness: 1.33
# Kurtosis: 2.75
# SNR: 11.3 dB
#
# z-axis:
# Range: [-15.0, 18.0] m/s²
# Mean: 1.21 m/s²
# Std: 3.57
# Skewness: 0.55
# Kurtosis: -0.02
# SNR: 16.4 dB
#
# Session 4:
#
# x-axis:
# Range: [-9.9, 16.4] m/s²
# Mean: -1.84 m/s²
# Std: 4.81
# Skewness: 1.02
# Kurtosis: 0.25
# SNR: 17.7 dB
#
# y-axis:
# Range: [-13.2, 12.4] m/s²
# Mean: -7.02 m/s²
# Std: 2.03
# Skewness: 0.87
# Kurtosis: 3.30
# SNR: 14.6 dB
#
# z-axis:
# Range: [-10.4, 35.2] m/s²
# Mean: 2.04 m/s²
# Std: 4.15
# Skewness: 0.23
# Kurtosis: -0.91
# SNR: 16.1 dB
#
# Session 5:
#
# x-axis:
# Range: [-26.4, 15.2] m/s²
# Mean: 2.75 m/s²
# Std: 3.16
# Skewness: -1.33
# Kurtosis: 4.69
# SNR: 15.2 dB
#
# y-axis:
# Range: [-39.4, 26.1] m/s²
# Mean: -7.24 m/s²
# Std: 2.94
# Skewness: 1.47
# Kurtosis: 3.23
# SNR: 11.3 dB
#
# z-axis:
# Range: [-19.9, 37.3] m/s²
# Mean: -0.09 m/s²
# Std: 4.88
# Skewness: 0.51
# Kurtosis: -0.98
# SNR: 17.1 dB
#
# Session 6:
#
# x-axis:
# Range: [-8.2, 16.5] m/s²
# Mean: 2.39 m/s²
# Std: 1.74
# Skewness: -1.11
# Kurtosis: 3.64
# SNR: 18.7 dB
#
# y-axis:
# Range: [-19.0, 6.8] m/s²
# Mean: -7.68 m/s²
# Std: 2.87
# Skewness: 1.63
# Kurtosis: 2.07
# SNR: 16.8 dB
#
# z-axis:
# Range: [-6.3, 28.3] m/s²
# Mean: 3.43 m/s²
# Std: 3.58
# Skewness: 0.35
# Kurtosis: -0.74
# SNR: 20.2 dB
#
# Session 7:
#
# x-axis:
# Range: [-20.1, 30.0] m/s²
# Mean: -0.69 m/s²
# Std: 5.47
# Skewness: 0.83
# Kurtosis: -0.01
# SNR: 14.7 dB
#
# y-axis:
# Range: [-34.2, 17.7] m/s²
# Mean: -6.85 m/s²
# Std: 3.73
# Skewness: 1.56
# Kurtosis: 3.03
# SNR: 12.4 dB
#
# z-axis:
# Range: [-13.7, 17.4] m/s²
# Mean: 0.69 m/s²
# Std: 3.49
# Skewness: 0.69
# Kurtosis: 0.21
# SNR: 14.5 dB
#
# Session 8:
#
# x-axis:
# Range: [-9.7, 9.3] m/s²
# Mean: 2.66 m/s²
# Std: 1.99
# Skewness: -1.36
# Kurtosis: 3.14
# SNR: 15.6 dB
#
# y-axis:
# Range: [-16.6, 11.5] m/s²
# Mean: -6.80 m/s²
# Std: 3.72
# Skewness: 2.35
# Kurtosis: 5.05
# SNR: 14.2 dB
#
# z-axis:
# Range: [-9.6, 20.1] m/s²
# Mean: 2.62 m/s²
# Std: 4.05
# Skewness: -0.03
# Kurtosis: -0.64
# SNR: 18.7 dB
#
# Session 9:
#
# x-axis:
# Range: [-14.8, 15.2] m/s²
# Mean: -4.92 m/s²
# Std: 2.86
# Skewness: 1.22
# Kurtosis: 1.29
# SNR: 15.1 dB
#
# y-axis:
# Range: [-31.0, 16.6] m/s²
# Mean: -4.91 m/s²
# Std: 3.83
# Skewness: 1.76
# Kurtosis: 4.21
# SNR: 11.7 dB
#
# z-axis:
# Range: [-14.7, 22.3] m/s²
# Mean: 3.51 m/s²
# Std: 3.41
# Skewness: -0.47
# Kurtosis: -0.44
# SNR: 15.8 dB
#
# Session 10:
#
# x-axis:
# Range: [-14.1, 33.6] m/s²
# Mean: 3.03 m/s²
# Std: 6.71
# Skewness: 0.03
# Kurtosis: -1.09
# SNR: 13.7 dB
#
# y-axis:
# Range: [-31.1, 13.4] m/s²
# Mean: -5.18 m/s²
# Std: 3.17
# Skewness: 0.22
# Kurtosis: -0.04
# SNR: 10.8 dB
#
# z-axis:
# Range: [-34.4, 19.6] m/s²
# Mean: 2.88 m/s²
# Std: 3.42
# Skewness: -0.51
# Kurtosis: 1.22
# SNR: 13.2 dB
#
# Session 11:
#
# x-axis:
# Range: [-13.8, 5.4] m/s²
# Mean: -2.36 m/s²
# Std: 2.53
# Skewness: -0.16
# Kurtosis: -0.34
# SNR: 16.8 dB
#
# y-axis:
# Range: [-22.7, 4.1] m/s²
# Mean: -6.24 m/s²
# Std: 2.76
# Skewness: 0.91
# Kurtosis: 0.40
# SNR: 9.5 dB
#
# z-axis:
# Range: [-6.5, 15.6] m/s²
# Mean: 4.86 m/s²
# Std: 3.64
# Skewness: -0.37
# Kurtosis: -0.69
# SNR: 17.1 dB
#
# Session 12:
#
# x-axis:
# Range: [-11.8, 17.8] m/s²
# Mean: -1.89 m/s²
# Std: 3.16
# Skewness: 1.07
# Kurtosis: 3.49
# SNR: 15.3 dB
#
# y-axis:
# Range: [-19.8, 13.6] m/s²
# Mean: -6.86 m/s²
# Std: 3.24
# Skewness: 1.28
# Kurtosis: 1.91
# SNR: 12.1 dB
#
# z-axis:
# Range: [-8.3, 41.2] m/s²
# Mean: 3.17 m/s²
# Std: 4.45
# Skewness: 0.04
# Kurtosis: -0.79
# SNR: 13.3 dB
#
# Session 13:
#
# x-axis:
# Range: [-18.2, 14.4] m/s²
# Mean: -1.55 m/s²
# Std: 3.63
# Skewness: 0.16
# Kurtosis: -0.04
# SNR: 13.6 dB
#
# y-axis:
# Range: [-29.7, 17.5] m/s²
# Mean: -5.69 m/s²
# Std: 3.70
# Skewness: 1.05
# Kurtosis: 0.92
# SNR: 9.7 dB
#
# z-axis:
# Range: [-14.2, 42.4] m/s²
# Mean: 3.90 m/s²
# Std: 4.90
# Skewness: -0.61
# Kurtosis: -0.56
# SNR: 13.7 dB
#
# Session 14:
#
# x-axis:
# Range: [-16.4, 15.8] m/s²
# Mean: -2.68 m/s²
# Std: 3.50
# Skewness: 0.04
# Kurtosis: 0.13
# SNR: 16.3 dB
#
# y-axis:
# Range: [-35.0, 13.7] m/s²
# Mean: -5.60 m/s²
# Std: 4.43
# Skewness: 0.73
# Kurtosis: -0.25
# SNR: 11.5 dB
#
# z-axis:
# Range: [-20.0, 41.4] m/s²
# Mean: 3.91 m/s²
# Std: 3.86
# Skewness: 0.05
# Kurtosis: -0.87
# SNR: 13.1 dB
#
# Session 15:
#
# x-axis:
# Range: [-12.4, 17.2] m/s²
# Mean: -1.30 m/s²
# Std: 3.75
# Skewness: 0.41
# Kurtosis: -0.04
# SNR: 17.4 dB
#
# y-axis:
# Range: [-24.3, 11.8] m/s²
# Mean: -5.76 m/s²
# Std: 3.80
# Skewness: 0.87
# Kurtosis: 0.38
# SNR: 12.9 dB
#
# z-axis:
# Range: [-14.5, 17.6] m/s²
# Mean: 4.27 m/s²
# Std: 4.48
# Skewness: -0.33
# Kurtosis: -0.93
# SNR: 16.5 dB
#
# Session 16:
#
# x-axis:
# Range: [-37.2, 14.4] m/s²
# Mean: -0.63 m/s²
# Std: 5.69
# Skewness: -0.37
# Kurtosis: -0.45
# SNR: 12.5 dB
#
# y-axis:
# Range: [-38.1, 21.8] m/s²
# Mean: -4.19 m/s²
# Std: 3.98
# Skewness: 0.01
# Kurtosis: -0.57
# SNR: 10.2 dB
#
# z-axis:
# Range: [-16.6, 40.7] m/s²
# Mean: 4.93 m/s²
# Std: 3.90
# Skewness: -0.43
# Kurtosis: 0.10
# SNR: 12.3 dB
#
# Session 17:
#
# x-axis:
# Range: [-10.0, 22.8] m/s²
# Mean: -2.03 m/s²
# Std: 2.88
# Skewness: 1.43
# Kurtosis: 3.22
# SNR: 15.1 dB
#
# y-axis:
# Range: [-22.0, 11.4] m/s²
# Mean: -7.87 m/s²
# Std: 2.33
# Skewness: 1.68
# Kurtosis: 4.59
# SNR: 12.1 dB
#
# z-axis:
# Range: [-11.1, 54.6] m/s²
# Mean: 1.05 m/s²
# Std: 4.62
# Skewness: 0.91
# Kurtosis: 1.40
# SNR: 12.5 dB
#
# Session 18:
#
# x-axis:
# Range: [-15.3, 9.4] m/s²
# Mean: -1.32 m/s²
# Std: 1.92
# Skewness: -1.64
# Kurtosis: 4.40
# SNR: 14.7 dB
#
# y-axis:
# Range: [-37.3, 14.9] m/s²
# Mean: -6.27 m/s²
# Std: 3.63
# Skewness: 0.74
# Kurtosis: -0.08
# SNR: 10.6 dB
#
# z-axis:
# Range: [-22.9, 24.7] m/s²
# Mean: 4.19 m/s²
# Std: 4.35
# Skewness: 0.05
# Kurtosis: -1.29
# SNR: 12.2 dB
#
# Session 19:
#
# x-axis:
# Range: [-10.4, 24.1] m/s²
# Mean: -1.62 m/s²
# Std: 3.38
# Skewness: 1.99
# Kurtosis: 4.46
# SNR: 16.0 dB
#
# y-axis:
# Range: [-32.5, 14.3] m/s²
# Mean: -6.15 m/s²
# Std: 2.94
# Skewness: 1.33
# Kurtosis: 2.94
# SNR: 11.3 dB
#
# z-axis:
# Range: [-21.0, 35.0] m/s²
# Mean: 3.75 m/s²
# Std: 4.89
# Skewness: -0.52
# Kurtosis: -0.83
# SNR: 13.9 dB
#
# Session 20:
#
# x-axis:
# Range: [-12.5, 30.4] m/s²
# Mean: 2.21 m/s²
# Std: 5.61
# Skewness: 0.36
# Kurtosis: -0.54
# SNR: 14.5 dB
#
# y-axis:
# Range: [-35.0, 11.7] m/s²
# Mean: -5.40 m/s²
# Std: 3.13
# Skewness: 0.46
# Kurtosis: 1.01
# SNR: 11.0 dB
#
# z-axis:
# Range: [-17.8, 21.2] m/s²
# Mean: 4.20 m/s²
# Std: 3.68
# Skewness: -0.82
# Kurtosis: 0.43
# SNR: 13.5 dB
#
# Session 21:
#
# x-axis:
# Range: [-14.6, 10.9] m/s²
# Mean: -2.78 m/s²
# Std: 2.37
# Skewness: 0.42
# Kurtosis: 1.32
# SNR: 16.3 dB
#
# y-axis:
# Range: [-40.1, 15.6] m/s²
# Mean: -6.42 m/s²
# Std: 2.81
# Skewness: 1.32
# Kurtosis: 3.99
# SNR: 11.2 dB
#
# z-axis:
# Range: [-15.9, 16.2] m/s²
# Mean: 1.60 m/s²
# Std: 5.40
# Skewness: 0.03
# Kurtosis: -1.32
# SNR: 20.0 dB
#
# Session 22:
#
# x-axis:
# Range: [-13.5, 13.5] m/s²
# Mean: -1.69 m/s²
# Std: 1.35
# Skewness: 0.30
# Kurtosis: 5.20
# SNR: 14.1 dB
#
# y-axis:
# Range: [-25.3, 6.8] m/s²
# Mean: -8.38 m/s²
# Std: 2.18
# Skewness: 1.68
# Kurtosis: 2.51
# SNR: 12.7 dB
#
# z-axis:
# Range: [-10.1, 33.0] m/s²
# Mean: 0.66 m/s²
# Std: 4.54
# Skewness: 0.68
# Kurtosis: -0.85
# SNR: 17.8 dB
#
# Session 23:
#
# x-axis:
# Range: [-13.2, 27.7] m/s²
# Mean: 2.33 m/s²
# Std: 6.06
# Skewness: 0.30
# Kurtosis: -1.23
# SNR: 15.1 dB
#
# y-axis:
# Range: [-27.5, 25.1] m/s²
# Mean: -5.00 m/s²
# Std: 3.25
# Skewness: 0.52
# Kurtosis: 0.18
# SNR: 9.5 dB
#
# z-axis:
# Range: [-28.1, 15.6] m/s²
# Mean: 0.76 m/s²
# Std: 4.68
# Skewness: -0.10
# Kurtosis: -0.65
# SNR: 14.1 dB
#
# Session 24:
#
# x-axis:
# Range: [-17.0, 14.3] m/s²
# Mean: -3.64 m/s²
# Std: 3.10
# Skewness: 0.55
# Kurtosis: 0.74
# SNR: 16.0 dB
#
# y-axis:
# Range: [-24.0, 9.9] m/s²
# Mean: -4.76 m/s²
# Std: 3.50
# Skewness: 0.13
# Kurtosis: -0.70
# SNR: 16.7 dB
#
# z-axis:
# Range: [-8.4, 31.6] m/s²
# Mean: 5.31 m/s²
# Std: 3.73
# Skewness: -0.48
# Kurtosis: -0.92
# SNR: 17.6 dB
#
# Session 25:
#
# x-axis:
# Range: [-13.3, 16.7] m/s²
# Mean: -1.08 m/s²
# Std: 3.69
# Skewness: 0.18
# Kurtosis: -0.52
# SNR: 19.0 dB
#
# y-axis:
# Range: [-30.8, 10.4] m/s²
# Mean: -7.11 m/s²
# Std: 2.64
# Skewness: 1.91
# Kurtosis: 6.35
# SNR: 12.3 dB
#
# z-axis:
# Range: [-17.3, 36.6] m/s²
# Mean: 3.11 m/s²
# Std: 4.35
# Skewness: -0.56
# Kurtosis: -0.83
# SNR: 14.3 dB
#
# Session 26:
#
# x-axis:
# Range: [-18.7, 28.3] m/s²
# Mean: -1.87 m/s²
# Std: 2.79
# Skewness: 2.00
# Kurtosis: 6.14
# SNR: 13.1 dB
#
# y-axis:
# Range: [-42.0, 11.7] m/s²
# Mean: -7.81 m/s²
# Std: 2.36
# Skewness: 1.20
# Kurtosis: 4.98
# SNR: 9.2 dB
#
# z-axis:
# Range: [-29.0, 50.0] m/s²
# Mean: 2.68 m/s²
# Std: 4.11
# Skewness: -0.25
# Kurtosis: 0.47
# SNR: 13.1 dB
#
# Gyroscope Statistics:
#
# Session 1:
#
# x-axis:
# Range: [-13.8, 11.2] rad/s
# Mean: -0.01 rad/s
# Std: 1.12
# Skewness: -0.41
# Kurtosis: 11.11
# SNR: 10.1 dB
#
# y-axis:
# Range: [-7.6, 6.7] rad/s
# Mean: 0.01 rad/s
# Std: 0.48
# Skewness: 0.04
# Kurtosis: 17.98
# SNR: 14.2 dB
#
# z-axis:
# Range: [-8.4, 5.1] rad/s
# Mean: 0.00 rad/s
# Std: 0.48
# Skewness: -0.49
# Kurtosis: 23.29
# SNR: 14.7 dB
#
# Session 2:
#
# x-axis:
# Range: [-19.9, 25.5] rad/s
# Mean: 0.00 rad/s
# Std: 1.58
# Skewness: 0.57
# Kurtosis: 23.39
# SNR: 11.0 dB
#
# y-axis:
# Range: [-9.3, 13.0] rad/s
# Mean: 0.03 rad/s
# Std: 0.74
# Skewness: 0.60
# Kurtosis: 19.20
# SNR: 14.2 dB
#
# z-axis:
# Range: [-9.1, 12.8] rad/s
# Mean: -0.00 rad/s
# Std: 0.93
# Skewness: 1.04
# Kurtosis: 19.77
# SNR: 17.4 dB
#
# Session 3:
#
# x-axis:
# Range: [-12.8, 30.0] rad/s
# Mean: -0.01 rad/s
# Std: 1.05
# Skewness: 0.18
# Kurtosis: 26.42
# SNR: 11.2 dB
#
# y-axis:
# Range: [-5.9, 26.8] rad/s
# Mean: -0.01 rad/s
# Std: 0.62
# Skewness: 2.13
# Kurtosis: 91.85
# SNR: 12.2 dB
#
# z-axis:
# Range: [-9.4, 28.4] rad/s
# Mean: -0.01 rad/s
# Std: 0.73
# Skewness: 1.31
# Kurtosis: 67.27
# SNR: 13.8 dB
#
# Session 4:
#
# x-axis:
# Range: [-5.7, 5.4] rad/s
# Mean: 0.00 rad/s
# Std: 0.64
# Skewness: 0.95
# Kurtosis: 9.63
# SNR: 14.9 dB
#
# y-axis:
# Range: [-3.9, 2.4] rad/s
# Mean: -0.03 rad/s
# Std: 0.28
# Skewness: -0.76
# Kurtosis: 14.51
# SNR: 16.2 dB
#
# z-axis:
# Range: [-3.4, 4.3] rad/s
# Mean: 0.01 rad/s
# Std: 0.37
# Skewness: 0.46
# Kurtosis: 20.33
# SNR: 22.7 dB
#
# Session 5:
#
# x-axis:
# Range: [-24.7, 28.9] rad/s
# Mean: 0.02 rad/s
# Std: 1.10
# Skewness: 0.38
# Kurtosis: 58.67
# SNR: 10.7 dB
#
# y-axis:
# Range: [-7.5, 5.6] rad/s
# Mean: 0.01 rad/s
# Std: 0.52
# Skewness: -0.13
# Kurtosis: 15.41
# SNR: 16.8 dB
#
# z-axis:
# Range: [-8.3, 8.4] rad/s
# Mean: 0.02 rad/s
# Std: 0.53
# Skewness: 0.74
# Kurtosis: 31.36
# SNR: 18.5 dB
#
# Session 6:
#
# x-axis:
# Range: [-6.8, 6.9] rad/s
# Mean: -0.00 rad/s
# Std: 0.76
# Skewness: 0.48
# Kurtosis: 13.80
# SNR: 16.1 dB
#
# y-axis:
# Range: [-3.4, 3.0] rad/s
# Mean: 0.02 rad/s
# Std: 0.27
# Skewness: -0.64
# Kurtosis: 20.78
# SNR: 20.9 dB
#
# z-axis:
# Range: [-2.5, 4.3] rad/s
# Mean: -0.00 rad/s
# Std: 0.27
# Skewness: 2.90
# Kurtosis: 45.93
# SNR: 21.6 dB
#
# Session 7:
#
# x-axis:
# Range: [-12.2, 30.0] rad/s
# Mean: 0.00 rad/s
# Std: 0.98
# Skewness: -0.08
# Kurtosis: 22.00
# SNR: 9.6 dB
#
# y-axis:
# Range: [-7.1, 29.4] rad/s
# Mean: 0.00 rad/s
# Std: 0.52
# Skewness: 2.20
# Kurtosis: 129.69
# SNR: 13.3 dB
#
# z-axis:
# Range: [-7.9, 29.5] rad/s
# Mean: -0.00 rad/s
# Std: 0.80
# Skewness: 0.37
# Kurtosis: 35.08
# SNR: 16.9 dB
#
# Session 8:
#
# x-axis:
# Range: [-11.0, 12.5] rad/s
# Mean: 0.00 rad/s
# Std: 0.72
# Skewness: 0.90
# Kurtosis: 27.72
# SNR: 13.3 dB
#
# y-axis:
# Range: [-2.2, 1.6] rad/s
# Mean: 0.01 rad/s
# Std: 0.27
# Skewness: -0.49
# Kurtosis: 5.90
# SNR: 19.3 dB
#
# z-axis:
# Range: [-2.3, 1.7] rad/s
# Mean: -0.01 rad/s
# Std: 0.21
# Skewness: -0.11
# Kurtosis: 11.17
# SNR: 16.9 dB
#
# Session 9:
#
# x-axis:
# Range: [-9.9, 11.8] rad/s
# Mean: -0.01 rad/s
# Std: 0.70
# Skewness: 0.80
# Kurtosis: 18.22
# SNR: 11.8 dB
#
# y-axis:
# Range: [-5.2, 5.1] rad/s
# Mean: -0.00 rad/s
# Std: 0.39
# Skewness: -0.25
# Kurtosis: 20.28
# SNR: 14.7 dB
#
# z-axis:
# Range: [-6.2, 3.4] rad/s
# Mean: 0.00 rad/s
# Std: 0.34
# Skewness: -1.35
# Kurtosis: 31.55
# SNR: 15.0 dB
#
# Session 10:
#
# x-axis:
# Range: [-15.1, 25.3] rad/s
# Mean: 0.00 rad/s
# Std: 0.94
# Skewness: 0.75
# Kurtosis: 38.69
# SNR: 13.2 dB
#
# y-axis:
# Range: [-4.9, 5.3] rad/s
# Mean: -0.01 rad/s
# Std: 0.65
# Skewness: -0.11
# Kurtosis: 7.42
# SNR: 18.9 dB
#
# z-axis:
# Range: [-8.1, 8.3] rad/s
# Mean: 0.01 rad/s
# Std: 1.26
# Skewness: 0.30
# Kurtosis: 5.52
# SNR: 28.9 dB
#
# Session 11:
#
# x-axis:
# Range: [-7.6, 7.4] rad/s
# Mean: 0.00 rad/s
# Std: 0.66
# Skewness: 1.07
# Kurtosis: 24.50
# SNR: 11.8 dB
#
# y-axis:
# Range: [-2.5, 5.2] rad/s
# Mean: 0.00 rad/s
# Std: 0.29
# Skewness: 3.17
# Kurtosis: 54.29
# SNR: 16.5 dB
#
# z-axis:
# Range: [-4.5, 4.2] rad/s
# Mean: 0.00 rad/s
# Std: 0.29
# Skewness: -0.60
# Kurtosis: 53.98
# SNR: 19.0 dB
#
# Session 12:
#
# x-axis:
# Range: [-6.5, 5.6] rad/s
# Mean: 0.00 rad/s
# Std: 0.57
# Skewness: 0.40
# Kurtosis: 15.39
# SNR: 14.5 dB
#
# y-axis:
# Range: [-4.1, 3.8] rad/s
# Mean: 0.01 rad/s
# Std: 0.28
# Skewness: 0.82
# Kurtosis: 34.06
# SNR: 17.0 dB
#
# z-axis:
# Range: [-4.1, 4.3] rad/s
# Mean: 0.02 rad/s
# Std: 0.29
# Skewness: 0.67
# Kurtosis: 40.09
# SNR: 19.9 dB
#
# Session 13:
#
# x-axis:
# Range: [-13.7, 30.0] rad/s
# Mean: -0.00 rad/s
# Std: 0.84
# Skewness: 0.47
# Kurtosis: 40.23
# SNR: 9.6 dB
#
# y-axis:
# Range: [-3.9, 24.5] rad/s
# Mean: 0.01 rad/s
# Std: 0.39
# Skewness: 1.72
# Kurtosis: 121.43
# SNR: 13.6 dB
#
# z-axis:
# Range: [-5.1, 27.0] rad/s
# Mean: 0.00 rad/s
# Std: 0.38
# Skewness: 2.38
# Kurtosis: 185.00
# SNR: 12.8 dB
#
# Session 14:
#
# x-axis:
# Range: [-11.1, 15.8] rad/s
# Mean: -0.00 rad/s
# Std: 0.64
# Skewness: 1.19
# Kurtosis: 60.47
# SNR: 11.4 dB
#
# y-axis:
# Range: [-6.3, 5.8] rad/s
# Mean: -0.00 rad/s
# Std: 0.36
# Skewness: -1.34
# Kurtosis: 44.63
# SNR: 15.4 dB
#
# z-axis:
# Range: [-7.4, 4.8] rad/s
# Mean: -0.00 rad/s
# Std: 0.34
# Skewness: -0.65
# Kurtosis: 59.73
# SNR: 17.5 dB
#
# Session 15:
#
# x-axis:
# Range: [-8.9, 8.6] rad/s
# Mean: -0.01 rad/s
# Std: 0.94
# Skewness: 0.08
# Kurtosis: 9.52
# SNR: 12.1 dB
#
# y-axis:
# Range: [-3.9, 4.2] rad/s
# Mean: 0.01 rad/s
# Std: 0.45
# Skewness: 0.11
# Kurtosis: 9.99
# SNR: 18.2 dB
#
# z-axis:
# Range: [-4.4, 4.0] rad/s
# Mean: 0.01 rad/s
# Std: 0.44
# Skewness: 0.04
# Kurtosis: 13.62
# SNR: 20.4 dB
#
# Session 16:
#
# x-axis:
# Range: [-30.1, 16.2] rad/s
# Mean: -0.01 rad/s
# Std: 1.34
# Skewness: -0.04
# Kurtosis: 17.93
# SNR: 9.6 dB
#
# y-axis:
# Range: [-17.9, 7.5] rad/s
# Mean: -0.01 rad/s
# Std: 0.72
# Skewness: -0.29
# Kurtosis: 15.68
# SNR: 11.9 dB
#
# z-axis:
# Range: [-21.5, 8.4] rad/s
# Mean: -0.01 rad/s
# Std: 0.70
# Skewness: 0.19
# Kurtosis: 27.22
# SNR: 13.2 dB
#
# Session 17:
#
# x-axis:
# Range: [-10.1, 11.4] rad/s
# Mean: -0.01 rad/s
# Std: 0.73
# Skewness: 0.03
# Kurtosis: 28.12
# SNR: 13.1 dB
#
# y-axis:
# Range: [-7.9, 4.7] rad/s
# Mean: -0.02 rad/s
# Std: 0.42
# Skewness: -1.41
# Kurtosis: 40.87
# SNR: 13.1 dB
#
# z-axis:
# Range: [-6.6, 6.9] rad/s
# Mean: -0.00 rad/s
# Std: 0.44
# Skewness: -0.18
# Kurtosis: 43.33
# SNR: 19.8 dB
#
# Session 18:
#
# x-axis:
# Range: [-5.6, 11.7] rad/s
# Mean: -0.01 rad/s
# Std: 0.87
# Skewness: 0.22
# Kurtosis: 11.50
# SNR: 13.8 dB
#
# y-axis:
# Range: [-4.3, 3.8] rad/s
# Mean: -0.00 rad/s
# Std: 0.26
# Skewness: 0.75
# Kurtosis: 20.48
# SNR: 14.5 dB
#
# z-axis:
# Range: [-4.6, 5.3] rad/s
# Mean: 0.01 rad/s
# Std: 0.45
# Skewness: -0.25
# Kurtosis: 34.24
# SNR: 19.9 dB
#
# Session 19:
#
# x-axis:
# Range: [-10.2, 13.3] rad/s
# Mean: -0.02 rad/s
# Std: 0.93
# Skewness: -0.10
# Kurtosis: 14.93
# SNR: 11.6 dB
#
# y-axis:
# Range: [-6.6, 6.7] rad/s
# Mean: 0.02 rad/s
# Std: 0.48
# Skewness: 0.28
# Kurtosis: 14.51
# SNR: 18.0 dB
#
# z-axis:
# Range: [-8.4, 5.0] rad/s
# Mean: 0.01 rad/s
# Std: 0.53
# Skewness: -1.32
# Kurtosis: 28.01
# SNR: 19.7 dB
#
# Session 20:
#
# x-axis:
# Range: [-30.1, 14.5] rad/s
# Mean: 0.00 rad/s
# Std: 1.01
# Skewness: -0.36
# Kurtosis: 19.50
# SNR: 12.1 dB
#
# y-axis:
# Range: [-30.0, 6.1] rad/s
# Mean: -0.00 rad/s
# Std: 0.64
# Skewness: -1.08
# Kurtosis: 42.28
# SNR: 15.8 dB
#
# z-axis:
# Range: [-30.0, 6.9] rad/s
# Mean: -0.00 rad/s
# Std: 0.92
# Skewness: -0.35
# Kurtosis: 17.03
# SNR: 19.2 dB
#
# Session 21:
#
# x-axis:
# Range: [-13.1, 14.0] rad/s
# Mean: -0.01 rad/s
# Std: 1.15
# Skewness: 0.69
# Kurtosis: 9.33
# SNR: 14.1 dB
#
# y-axis:
# Range: [-7.3, 3.5] rad/s
# Mean: -0.02 rad/s
# Std: 0.49
# Skewness: -0.38
# Kurtosis: 11.69
# SNR: 19.4 dB
#
# z-axis:
# Range: [-4.6, 4.3] rad/s
# Mean: 0.01 rad/s
# Std: 0.44
# Skewness: -0.05
# Kurtosis: 17.23
# SNR: 18.5 dB
#
# Session 22:
#
# x-axis:
# Range: [-13.4, 27.6] rad/s
# Mean: -0.00 rad/s
# Std: 0.68
# Skewness: 1.28
# Kurtosis: 52.09
# SNR: 10.4 dB
#
# y-axis:
# Range: [-6.1, 11.7] rad/s
# Mean: -0.00 rad/s
# Std: 0.27
# Skewness: 0.27
# Kurtosis: 88.92
# SNR: 10.6 dB
#
# z-axis:
# Range: [-4.0, 14.6] rad/s
# Mean: 0.00 rad/s
# Std: 0.25
# Skewness: 2.50
# Kurtosis: 170.90
# SNR: 11.6 dB
#
# Session 23:
#
# x-axis:
# Range: [-16.5, 13.1] rad/s
# Mean: -0.00 rad/s
# Std: 1.32
# Skewness: -0.49
# Kurtosis: 12.44
# SNR: 14.6 dB
#
# y-axis:
# Range: [-11.2, 9.3] rad/s
# Mean: 0.02 rad/s
# Std: 0.65
# Skewness: 0.69
# Kurtosis: 17.50
# SNR: 17.3 dB
#
# z-axis:
# Range: [-8.7, 7.2] rad/s
# Mean: -0.01 rad/s
# Std: 0.82
# Skewness: 0.07
# Kurtosis: 13.99
# SNR: 22.5 dB
#
# Session 24:
#
# x-axis:
# Range: [-23.8, 12.7] rad/s
# Mean: -0.00 rad/s
# Std: 0.99
# Skewness: 0.42
# Kurtosis: 15.94
# SNR: 13.5 dB
#
# y-axis:
# Range: [-8.4, 5.8] rad/s
# Mean: -0.02 rad/s
# Std: 0.39
# Skewness: 0.27
# Kurtosis: 18.49
# SNR: 15.5 dB
#
# z-axis:
# Range: [-10.9, 8.3] rad/s
# Mean: 0.00 rad/s
# Std: 0.44
# Skewness: -0.05
# Kurtosis: 60.61
# SNR: 16.2 dB
#
# Session 25:
#
# x-axis:
# Range: [-30.1, 12.0] rad/s
# Mean: -0.00 rad/s
# Std: 0.59
# Skewness: -0.13
# Kurtosis: 100.47
# SNR: 10.4 dB
#
# y-axis:
# Range: [-28.9, 5.3] rad/s
# Mean: -0.00 rad/s
# Std: 0.32
# Skewness: -6.07
# Kurtosis: 556.13
# SNR: 12.1 dB
#
# z-axis:
# Range: [-28.4, 6.9] rad/s
# Mean: 0.00 rad/s
# Std: 0.42
# Skewness: -2.37
# Kurtosis: 228.50
# SNR: 15.4 dB
#
# Session 26:
#
# x-axis:
# Range: [-12.2, 12.1] rad/s
# Mean: -0.01 rad/s
# Std: 0.90
# Skewness: 0.46
# Kurtosis: 19.53
# SNR: 12.0 dB
#
# y-axis:
# Range: [-7.6, 5.4] rad/s
# Mean: 0.01 rad/s
# Std: 0.37
# Skewness: -0.43
# Kurtosis: 34.49
# SNR: 12.2 dB
#
# z-axis:
# Range: [-7.2, 6.8] rad/s
# Mean: 0.00 rad/s
# Std: 0.43
# Skewness: 0.23
# Kurtosis: 43.39
# SNR: 16.9 dB
#
# Spectral Components:
#
# Session 1:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 73.0%
# Mid-frequency (3-10 Hz): 15.1%
# High-frequency (>10 Hz): 4.9%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 62.3%
# Mid-frequency (3-10 Hz): 22.0%
# High-frequency (>10 Hz): 10.8%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 80.0%
# Mid-frequency (3-10 Hz): 8.4%
# High-frequency (>10 Hz): 5.0%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 63.2%
# Mid-frequency (3-10 Hz): 26.4%
# High-frequency (>10 Hz): 8.8%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 71.6%
# Mid-frequency (3-10 Hz): 21.9%
# High-frequency (>10 Hz): 3.7%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 63.9%
# Mid-frequency (3-10 Hz): 30.3%
# High-frequency (>10 Hz): 3.3%
#
# Session 2:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 62.6%
# Mid-frequency (3-10 Hz): 28.9%
# High-frequency (>10 Hz): 3.2%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 53.0%
# Mid-frequency (3-10 Hz): 32.1%
# High-frequency (>10 Hz): 11.0%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 68.9%
# Mid-frequency (3-10 Hz): 20.2%
# High-frequency (>10 Hz): 5.5%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 33.1%
# Mid-frequency (3-10 Hz): 58.9%
# High-frequency (>10 Hz): 7.4%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 58.7%
# Mid-frequency (3-10 Hz): 36.2%
# High-frequency (>10 Hz): 3.7%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 62.4%
# Mid-frequency (3-10 Hz): 34.5%
# High-frequency (>10 Hz): 1.8%
#
# Session 3:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 75.3%
# Mid-frequency (3-10 Hz): 15.7%
# High-frequency (>10 Hz): 1.8%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 64.4%
# Mid-frequency (3-10 Hz): 23.8%
# High-frequency (>10 Hz): 7.0%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 81.1%
# Mid-frequency (3-10 Hz): 9.0%
# High-frequency (>10 Hz): 2.2%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 60.1%
# Mid-frequency (3-10 Hz): 31.3%
# High-frequency (>10 Hz): 7.0%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 69.4%
# Mid-frequency (3-10 Hz): 22.5%
# High-frequency (>10 Hz): 5.7%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 75.6%
# Mid-frequency (3-10 Hz): 18.5%
# High-frequency (>10 Hz): 4.0%
#
# Session 4:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 84.1%
# Mid-frequency (3-10 Hz): 4.7%
# High-frequency (>10 Hz): 1.7%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 82.0%
# Mid-frequency (3-10 Hz): 6.6%
# High-frequency (>10 Hz): 3.3%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 85.6%
# Mid-frequency (3-10 Hz): 3.1%
# High-frequency (>10 Hz): 2.4%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 77.9%
# Mid-frequency (3-10 Hz): 15.1%
# High-frequency (>10 Hz): 3.2%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 76.8%
# Mid-frequency (3-10 Hz): 17.5%
# High-frequency (>10 Hz): 2.4%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 87.2%
# Mid-frequency (3-10 Hz): 9.0%
# High-frequency (>10 Hz): 0.5%
#
# Session 5:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 77.6%
# Mid-frequency (3-10 Hz): 12.0%
# High-frequency (>10 Hz): 2.9%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 73.4%
# Mid-frequency (3-10 Hz): 13.5%
# High-frequency (>10 Hz): 6.9%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 82.5%
# Mid-frequency (3-10 Hz): 5.5%
# High-frequency (>10 Hz): 1.9%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 55.4%
# Mid-frequency (3-10 Hz): 35.0%
# High-frequency (>10 Hz): 7.9%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 73.1%
# Mid-frequency (3-10 Hz): 22.4%
# High-frequency (>10 Hz): 2.0%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 76.5%
# Mid-frequency (3-10 Hz): 19.4%
# High-frequency (>10 Hz): 1.4%
#
# Session 6:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 79.3%
# Mid-frequency (3-10 Hz): 10.2%
# High-frequency (>10 Hz): 1.3%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 80.3%
# Mid-frequency (3-10 Hz): 10.9%
# High-frequency (>10 Hz): 2.1%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 86.2%
# Mid-frequency (3-10 Hz): 4.6%
# High-frequency (>10 Hz): 0.9%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 67.6%
# Mid-frequency (3-10 Hz): 27.4%
# High-frequency (>10 Hz): 2.4%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 73.8%
# Mid-frequency (3-10 Hz): 23.8%
# High-frequency (>10 Hz): 0.8%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 75.6%
# Mid-frequency (3-10 Hz): 21.4%
# High-frequency (>10 Hz): 0.7%
#
# Session 7:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 67.4%
# Mid-frequency (3-10 Hz): 22.9%
# High-frequency (>10 Hz): 3.3%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 71.6%
# Mid-frequency (3-10 Hz): 17.4%
# High-frequency (>10 Hz): 5.5%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 78.7%
# Mid-frequency (3-10 Hz): 11.1%
# High-frequency (>10 Hz): 3.4%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 48.1%
# Mid-frequency (3-10 Hz): 41.0%
# High-frequency (>10 Hz): 9.8%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 75.7%
# Mid-frequency (3-10 Hz): 17.4%
# High-frequency (>10 Hz): 4.5%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 80.2%
# Mid-frequency (3-10 Hz): 16.1%
# High-frequency (>10 Hz): 2.0%
#
# Session 8:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 77.5%
# Mid-frequency (3-10 Hz): 11.4%
# High-frequency (>10 Hz): 2.7%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 82.0%
# Mid-frequency (3-10 Hz): 6.4%
# High-frequency (>10 Hz): 3.7%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 85.1%
# Mid-frequency (3-10 Hz): 5.3%
# High-frequency (>10 Hz): 1.3%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 67.3%
# Mid-frequency (3-10 Hz): 25.6%
# High-frequency (>10 Hz): 4.4%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 71.2%
# Mid-frequency (3-10 Hz): 25.2%
# High-frequency (>10 Hz): 1.1%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 70.1%
# Mid-frequency (3-10 Hz): 25.8%
# High-frequency (>10 Hz): 2.0%
#
# Session 9:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 78.2%
# Mid-frequency (3-10 Hz): 12.2%
# High-frequency (>10 Hz): 3.0%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 76.3%
# Mid-frequency (3-10 Hz): 11.5%
# High-frequency (>10 Hz): 6.4%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 83.2%
# Mid-frequency (3-10 Hz): 7.4%
# High-frequency (>10 Hz): 2.6%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 64.4%
# Mid-frequency (3-10 Hz): 27.6%
# High-frequency (>10 Hz): 6.1%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 63.0%
# Mid-frequency (3-10 Hz): 32.1%
# High-frequency (>10 Hz): 3.3%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 68.6%
# Mid-frequency (3-10 Hz): 25.5%
# High-frequency (>10 Hz): 3.1%
#
# Session 10:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 48.4%
# Mid-frequency (3-10 Hz): 44.4%
# High-frequency (>10 Hz): 4.1%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 62.2%
# Mid-frequency (3-10 Hz): 25.7%
# High-frequency (>10 Hz): 7.7%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 70.2%
# Mid-frequency (3-10 Hz): 19.3%
# High-frequency (>10 Hz): 4.5%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 43.8%
# Mid-frequency (3-10 Hz): 50.7%
# High-frequency (>10 Hz): 4.5%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 84.9%
# Mid-frequency (3-10 Hz): 13.1%
# High-frequency (>10 Hz): 1.3%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 93.0%
# Mid-frequency (3-10 Hz): 6.5%
# High-frequency (>10 Hz): 0.1%
#
# Session 11:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 81.8%
# Mid-frequency (3-10 Hz): 8.1%
# High-frequency (>10 Hz): 2.0%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 71.7%
# Mid-frequency (3-10 Hz): 12.2%
# High-frequency (>10 Hz): 10.1%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 84.5%
# Mid-frequency (3-10 Hz): 7.7%
# High-frequency (>10 Hz): 1.9%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 62.8%
# Mid-frequency (3-10 Hz): 29.7%
# High-frequency (>10 Hz): 6.2%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 67.4%
# Mid-frequency (3-10 Hz): 27.9%
# High-frequency (>10 Hz): 2.2%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 77.3%
# Mid-frequency (3-10 Hz): 17.9%
# High-frequency (>10 Hz): 1.2%
#
# Session 12:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 81.7%
# Mid-frequency (3-10 Hz): 7.7%
# High-frequency (>10 Hz): 2.9%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 68.6%
# Mid-frequency (3-10 Hz): 21.0%
# High-frequency (>10 Hz): 5.8%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 79.5%
# Mid-frequency (3-10 Hz): 8.4%
# High-frequency (>10 Hz): 4.5%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 68.4%
# Mid-frequency (3-10 Hz): 25.5%
# High-frequency (>10 Hz): 3.4%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 74.9%
# Mid-frequency (3-10 Hz): 20.8%
# High-frequency (>10 Hz): 2.0%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 74.5%
# Mid-frequency (3-10 Hz): 21.3%
# High-frequency (>10 Hz): 1.0%
#
# Session 13:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 64.0%
# Mid-frequency (3-10 Hz): 26.8%
# High-frequency (>10 Hz): 4.2%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 66.7%
# Mid-frequency (3-10 Hz): 17.9%
# High-frequency (>10 Hz): 9.7%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 77.4%
# Mid-frequency (3-10 Hz): 10.8%
# High-frequency (>10 Hz): 4.1%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 51.2%
# Mid-frequency (3-10 Hz): 37.4%
# High-frequency (>10 Hz): 9.9%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 68.0%
# Mid-frequency (3-10 Hz): 25.8%
# High-frequency (>10 Hz): 4.2%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 71.6%
# Mid-frequency (3-10 Hz): 21.4%
# High-frequency (>10 Hz): 5.0%
#
# Session 14:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 81.6%
# Mid-frequency (3-10 Hz): 11.9%
# High-frequency (>10 Hz): 2.3%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 71.8%
# Mid-frequency (3-10 Hz): 16.4%
# High-frequency (>10 Hz): 6.6%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 72.2%
# Mid-frequency (3-10 Hz): 17.0%
# High-frequency (>10 Hz): 4.6%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 54.5%
# Mid-frequency (3-10 Hz): 36.7%
# High-frequency (>10 Hz): 6.7%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 58.4%
# Mid-frequency (3-10 Hz): 37.3%
# High-frequency (>10 Hz): 2.8%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 64.9%
# Mid-frequency (3-10 Hz): 31.1%
# High-frequency (>10 Hz): 1.8%
#
# Session 15:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 79.6%
# Mid-frequency (3-10 Hz): 11.1%
# High-frequency (>10 Hz): 1.8%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 77.5%
# Mid-frequency (3-10 Hz): 10.4%
# High-frequency (>10 Hz): 4.9%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 84.2%
# Mid-frequency (3-10 Hz): 5.8%
# High-frequency (>10 Hz): 2.2%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 67.3%
# Mid-frequency (3-10 Hz): 24.7%
# High-frequency (>10 Hz): 5.9%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 78.7%
# Mid-frequency (3-10 Hz): 16.7%
# High-frequency (>10 Hz): 1.5%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 81.8%
# Mid-frequency (3-10 Hz): 13.7%
# High-frequency (>10 Hz): 0.9%
#
# Session 16:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 56.5%
# Mid-frequency (3-10 Hz): 34.8%
# High-frequency (>10 Hz): 5.3%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 64.4%
# Mid-frequency (3-10 Hz): 22.6%
# High-frequency (>10 Hz): 8.7%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 70.3%
# Mid-frequency (3-10 Hz): 18.2%
# High-frequency (>10 Hz): 5.6%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 47.2%
# Mid-frequency (3-10 Hz): 41.9%
# High-frequency (>10 Hz): 9.8%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 52.6%
# Mid-frequency (3-10 Hz): 40.6%
# High-frequency (>10 Hz): 6.1%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 63.9%
# Mid-frequency (3-10 Hz): 30.2%
# High-frequency (>10 Hz): 4.6%
#
# Session 17:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 77.9%
# Mid-frequency (3-10 Hz): 10.7%
# High-frequency (>10 Hz): 3.0%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 70.0%
# Mid-frequency (3-10 Hz): 16.6%
# High-frequency (>10 Hz): 5.9%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 73.7%
# Mid-frequency (3-10 Hz): 13.4%
# High-frequency (>10 Hz): 5.3%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 66.8%
# Mid-frequency (3-10 Hz): 26.0%
# High-frequency (>10 Hz): 4.7%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 55.7%
# Mid-frequency (3-10 Hz): 38.3%
# High-frequency (>10 Hz): 4.7%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 71.0%
# Mid-frequency (3-10 Hz): 25.6%
# High-frequency (>10 Hz): 1.0%
#
# Session 18:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 80.5%
# Mid-frequency (3-10 Hz): 7.6%
# High-frequency (>10 Hz): 3.3%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 75.0%
# Mid-frequency (3-10 Hz): 12.5%
# High-frequency (>10 Hz): 8.0%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 79.8%
# Mid-frequency (3-10 Hz): 8.5%
# High-frequency (>10 Hz): 5.7%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 71.3%
# Mid-frequency (3-10 Hz): 23.3%
# High-frequency (>10 Hz): 4.0%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 67.3%
# Mid-frequency (3-10 Hz): 27.9%
# High-frequency (>10 Hz): 3.4%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 81.8%
# Mid-frequency (3-10 Hz): 14.5%
# High-frequency (>10 Hz): 1.0%
#
# Session 19:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 76.8%
# Mid-frequency (3-10 Hz): 14.8%
# High-frequency (>10 Hz): 2.4%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 73.4%
# Mid-frequency (3-10 Hz): 13.7%
# High-frequency (>10 Hz): 6.8%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 80.3%
# Mid-frequency (3-10 Hz): 7.1%
# High-frequency (>10 Hz): 4.0%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 61.9%
# Mid-frequency (3-10 Hz): 29.8%
# High-frequency (>10 Hz): 6.4%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 75.0%
# Mid-frequency (3-10 Hz): 20.7%
# High-frequency (>10 Hz): 1.6%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 79.0%
# Mid-frequency (3-10 Hz): 17.7%
# High-frequency (>10 Hz): 1.1%
#
# Session 20:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 48.9%
# Mid-frequency (3-10 Hz): 43.7%
# High-frequency (>10 Hz): 3.4%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 59.8%
# Mid-frequency (3-10 Hz): 27.4%
# High-frequency (>10 Hz): 7.4%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 71.7%
# Mid-frequency (3-10 Hz): 18.1%
# High-frequency (>10 Hz): 4.3%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 40.0%
# Mid-frequency (3-10 Hz): 53.3%
# High-frequency (>10 Hz): 5.8%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 69.8%
# Mid-frequency (3-10 Hz): 26.9%
# High-frequency (>10 Hz): 2.6%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 72.9%
# Mid-frequency (3-10 Hz): 25.4%
# High-frequency (>10 Hz): 1.2%
#
# Session 21:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 81.4%
# Mid-frequency (3-10 Hz): 9.6%
# High-frequency (>10 Hz): 2.3%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 75.1%
# Mid-frequency (3-10 Hz): 12.5%
# High-frequency (>10 Hz): 7.1%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 85.9%
# Mid-frequency (3-10 Hz): 5.0%
# High-frequency (>10 Hz): 1.0%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 70.1%
# Mid-frequency (3-10 Hz): 24.7%
# High-frequency (>10 Hz): 3.8%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 73.8%
# Mid-frequency (3-10 Hz): 23.5%
# High-frequency (>10 Hz): 1.1%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 73.7%
# Mid-frequency (3-10 Hz): 23.2%
# High-frequency (>10 Hz): 1.4%
#
# Session 22:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 77.7%
# Mid-frequency (3-10 Hz): 11.9%
# High-frequency (>10 Hz): 3.7%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 74.8%
# Mid-frequency (3-10 Hz): 14.0%
# High-frequency (>10 Hz): 5.1%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 83.5%
# Mid-frequency (3-10 Hz): 4.3%
# High-frequency (>10 Hz): 1.6%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 63.3%
# Mid-frequency (3-10 Hz): 26.1%
# High-frequency (>10 Hz): 8.4%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 58.0%
# Mid-frequency (3-10 Hz): 32.3%
# High-frequency (>10 Hz): 8.0%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 62.7%
# Mid-frequency (3-10 Hz): 28.8%
# High-frequency (>10 Hz): 6.4%
#
# Session 23:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 70.6%
# Mid-frequency (3-10 Hz): 18.8%
# High-frequency (>10 Hz): 3.0%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 63.2%
# Mid-frequency (3-10 Hz): 22.7%
# High-frequency (>10 Hz): 10.2%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 77.0%
# Mid-frequency (3-10 Hz): 12.8%
# High-frequency (>10 Hz): 3.8%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 60.6%
# Mid-frequency (3-10 Hz): 34.9%
# High-frequency (>10 Hz): 3.3%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 67.6%
# Mid-frequency (3-10 Hz): 29.2%
# High-frequency (>10 Hz): 1.8%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 84.1%
# Mid-frequency (3-10 Hz): 13.8%
# High-frequency (>10 Hz): 0.6%
#
# Session 24:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 82.1%
# Mid-frequency (3-10 Hz): 7.7%
# High-frequency (>10 Hz): 2.5%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 83.9%
# Mid-frequency (3-10 Hz): 6.5%
# High-frequency (>10 Hz): 2.1%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 85.1%
# Mid-frequency (3-10 Hz): 4.4%
# High-frequency (>10 Hz): 1.7%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 74.2%
# Mid-frequency (3-10 Hz): 19.2%
# High-frequency (>10 Hz): 4.3%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 76.9%
# Mid-frequency (3-10 Hz): 17.5%
# High-frequency (>10 Hz): 2.7%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 80.4%
# Mid-frequency (3-10 Hz): 14.4%
# High-frequency (>10 Hz): 2.4%
#
# Session 25:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 83.7%
# Mid-frequency (3-10 Hz): 6.9%
# High-frequency (>10 Hz): 1.2%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 75.3%
# Mid-frequency (3-10 Hz): 12.8%
# High-frequency (>10 Hz): 5.5%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 79.6%
# Mid-frequency (3-10 Hz): 10.0%
# High-frequency (>10 Hz): 3.6%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 54.6%
# Mid-frequency (3-10 Hz): 35.2%
# High-frequency (>10 Hz): 8.3%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 70.8%
# Mid-frequency (3-10 Hz): 20.9%
# High-frequency (>10 Hz): 5.8%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 82.0%
# Mid-frequency (3-10 Hz): 11.0%
# High-frequency (>10 Hz): 2.8%
#
# Session 26:
#
# Accelerometer Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 77.2%
# Mid-frequency (3-10 Hz): 10.5%
# High-frequency (>10 Hz): 4.7%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 68.1%
# Mid-frequency (3-10 Hz): 16.6%
# High-frequency (>10 Hz): 10.7%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 80.5%
# Mid-frequency (3-10 Hz): 6.7%
# High-frequency (>10 Hz): 4.7%
#
# Gyroscope Spectral Components:
#
# Spectral components for x-axis:
# Low-frequency (0.1-3 Hz): 64.7%
# Mid-frequency (3-10 Hz): 27.9%
# High-frequency (>10 Hz): 6.0%
#
# Spectral components for y-axis:
# Low-frequency (0.1-3 Hz): 67.2%
# Mid-frequency (3-10 Hz): 24.3%
# High-frequency (>10 Hz): 5.6%
#
# Spectral components for z-axis:
# Low-frequency (0.1-3 Hz): 81.0%
# Mid-frequency (3-10 Hz): 13.7%
# High-frequency (>10 Hz): 2.0%
#
# Temporal Characteristics:
#
# Session 1:
# Mean Sampling Rate: 52.15 Hz
# Sampling Rate Std: 593.27 Hz
# Mean Temporal Offset: -14297.64 ms
# Temporal Offset Std: 4746.16 ms
#
# Session 2:
# Mean Sampling Rate: 52.79 Hz
# Sampling Rate Std: 768.76 Hz
# Mean Temporal Offset: -15704.64 ms
# Temporal Offset Std: 12575.78 ms
#
# Session 3:
# Mean Sampling Rate: 52.31 Hz
# Sampling Rate Std: 261.82 Hz
# Mean Temporal Offset: -9377.40 ms
# Temporal Offset Std: 4861.71 ms
#
# Session 4:
# Mean Sampling Rate: 51.55 Hz
# Sampling Rate Std: 5.56 Hz
# Mean Temporal Offset: 96.92 ms
# Temporal Offset Std: 3.15 ms
#
# Session 5:
# Mean Sampling Rate: 52.23 Hz
# Sampling Rate Std: 593.37 Hz
# Mean Temporal Offset: -11109.88 ms
# Temporal Offset Std: 7011.06 ms
#
# Session 6:
# Mean Sampling Rate: 51.55 Hz
# Sampling Rate Std: 14.23 Hz
# Mean Temporal Offset: 110.60 ms
# Temporal Offset Std: 1.40 ms
#
# Session 7:
# Mean Sampling Rate: 52.53 Hz
# Sampling Rate Std: 359.25 Hz
# Mean Temporal Offset: -17225.53 ms
# Temporal Offset Std: 7356.07 ms
#
# Session 8:
# Mean Sampling Rate: 51.03 Hz
# Sampling Rate Std: 10.78 Hz
# Mean Temporal Offset: -14607.98 ms
# Temporal Offset Std: 6294.56 ms
#
# Session 9:
# Mean Sampling Rate: 50.03 Hz
# Sampling Rate Std: 7.55 Hz
# Mean Temporal Offset: -11371.59 ms
# Temporal Offset Std: 4634.62 ms
#
# Session 10:
# Mean Sampling Rate: 52.41 Hz
# Sampling Rate Std: 415.25 Hz
# Mean Temporal Offset: -22015.31 ms
# Temporal Offset Std: 15772.82 ms
#
# Session 11:
# Mean Sampling Rate: 49.55 Hz
# Sampling Rate Std: 1.31 Hz
# Mean Temporal Offset: 5.60 ms
# Temporal Offset Std: 35.40 ms
#
# Session 12:
# Mean Sampling Rate: 51.55 Hz
# Sampling Rate Std: 15.66 Hz
# Mean Temporal Offset: 96.94 ms
# Temporal Offset Std: 4.64 ms
#
# Session 13:
# Mean Sampling Rate: 53.24 Hz
# Sampling Rate Std: 679.46 Hz
# Mean Temporal Offset: -66385.28 ms
# Temporal Offset Std: 31881.90 ms
#
# Session 14:
# Mean Sampling Rate: 52.73 Hz
# Sampling Rate Std: 350.83 Hz
# Mean Temporal Offset: -24601.39 ms
# Temporal Offset Std: 9956.76 ms
#
# Session 15:
# Mean Sampling Rate: 52.11 Hz
# Sampling Rate Std: 490.28 Hz
# Mean Temporal Offset: -10584.64 ms
# Temporal Offset Std: 6071.23 ms
#
# Session 16:
# Mean Sampling Rate: 54.77 Hz
# Sampling Rate Std: 911.86 Hz
# Mean Temporal Offset: -35398.60 ms
# Temporal Offset Std: 16870.36 ms
#
# Session 17:
# Mean Sampling Rate: 52.01 Hz
# Sampling Rate Std: 261.23 Hz
# Mean Temporal Offset: -4845.88 ms
# Temporal Offset Std: 2029.22 ms
#
# Session 18:
# Mean Sampling Rate: 51.79 Hz
# Sampling Rate Std: 13.11 Hz
# Mean Temporal Offset: -23224.73 ms
# Temporal Offset Std: 4237.92 ms
#
# Session 19:
# Mean Sampling Rate: 50.81 Hz
# Sampling Rate Std: 9.47 Hz
# Mean Temporal Offset: -20248.66 ms
# Temporal Offset Std: 9663.13 ms
#
# Session 20:
# Mean Sampling Rate: 52.59 Hz
# Sampling Rate Std: 390.24 Hz
# Mean Temporal Offset: -25593.98 ms
# Temporal Offset Std: 17309.30 ms
#
# Session 21:
# Mean Sampling Rate: 49.99 Hz
# Sampling Rate Std: 6.95 Hz
# Mean Temporal Offset: -4506.24 ms
# Temporal Offset Std: 1451.29 ms
#
# Session 22:
# Mean Sampling Rate: 51.83 Hz
# Sampling Rate Std: 262.81 Hz
# Mean Temporal Offset: -8434.80 ms
# Temporal Offset Std: 951.65 ms
#
# Session 23:
# Mean Sampling Rate: 50.41 Hz
# Sampling Rate Std: 7.20 Hz
# Mean Temporal Offset: -10108.20 ms
# Temporal Offset Std: 5130.00 ms
#
# Session 24:
# Mean Sampling Rate: 51.95 Hz
# Sampling Rate Std: 130.33 Hz
# Mean Temporal Offset: -5704.76 ms
# Temporal Offset Std: 3054.11 ms
#
# Session 25:
# Mean Sampling Rate: 52.12 Hz
# Sampling Rate Std: 286.87 Hz
# Mean Temporal Offset: -14341.20 ms
# Temporal Offset Std: 13382.59 ms
#
# Session 26:
# Mean Sampling Rate: 51.94 Hz
# Sampling Rate Std: 239.36 Hz
# Mean Temporal Offset: -6547.70 ms
# Temporal Offset Std: 2953.28 ms
#
# Data Quality Metrics:
#
# Session 1:
# Missing Samples: -0.00%
# Timestamp Continuity: 86.47%
# Sample Interval 95% CI: [15.2, 23.2] ms
#
# Session 2:
# Missing Samples: -0.00%
# Timestamp Continuity: 84.60%
# Sample Interval 95% CI: [13.7, 24.2] ms
#
# Session 3:
# Missing Samples: -0.00%
# Timestamp Continuity: 93.50%
# Sample Interval 95% CI: [15.3, 23.0] ms
#
# Session 4:
# Missing Samples: -0.01%
# Timestamp Continuity: 92.62%
# Sample Interval 95% CI: [17.6, 21.2] ms
#
# Session 5:
# Missing Samples: -0.00%
# Timestamp Continuity: 83.24%
# Sample Interval 95% CI: [14.8, 23.4] ms
#
# Session 6:
# Missing Samples: -0.01%
# Timestamp Continuity: 94.84%
# Sample Interval 95% CI: [17.8, 21.0] ms
#
# Session 7:
# Missing Samples: -0.00%
# Timestamp Continuity: 84.81%
# Sample Interval 95% CI: [14.3, 23.8] ms
#
# Session 8:
# Missing Samples: -0.00%
# Timestamp Continuity: 22.14%
# Sample Interval 95% CI: [15.3, 23.9] ms
#
# Session 9:
# Missing Samples: -0.00%
# Timestamp Continuity: 23.38%
# Sample Interval 95% CI: [-4.5, 44.4] ms
#
# Session 10:
# Missing Samples: -0.00%
# Timestamp Continuity: 89.58%
# Sample Interval 95% CI: [-131.5, 169.6] ms
#
# Session 11:
# Missing Samples: -0.01%
# Timestamp Continuity: 22.30%
# Sample Interval 95% CI: [19.1, 21.3] ms
#
# Session 12:
# Missing Samples: -0.00%
# Timestamp Continuity: 94.12%
# Sample Interval 95% CI: [17.7, 21.1] ms
#
# Session 13:
# Missing Samples: -0.00%
# Timestamp Continuity: 83.92%
# Sample Interval 95% CI: [13.3, 24.3] ms
#
# Session 14:
# Missing Samples: -0.00%
# Timestamp Continuity: 87.64%
# Sample Interval 95% CI: [14.3, 23.7] ms
#
# Session 15:
# Missing Samples: -0.00%
# Timestamp Continuity: 87.27%
# Sample Interval 95% CI: [15.3, 23.1] ms
#
# Session 16:
# Missing Samples: -0.00%
# Timestamp Continuity: 90.36%
# Sample Interval 95% CI: [11.1, 25.4] ms
#
# Session 17:
# Missing Samples: -0.01%
# Timestamp Continuity: 94.10%
# Sample Interval 95% CI: [15.9, 22.6] ms
#
# Session 18:
# Missing Samples: -0.01%
# Timestamp Continuity: 25.12%
# Sample Interval 95% CI: [14.1, 24.5] ms
#
# Session 19:
# Missing Samples: -0.00%
# Timestamp Continuity: 13.68%
# Sample Interval 95% CI: [15.9, 23.4] ms
#
# Session 20:
# Missing Samples: -0.00%
# Timestamp Continuity: 81.54%
# Sample Interval 95% CI: [14.1, 23.9] ms
#
# Session 21:
# Missing Samples: -0.01%
# Timestamp Continuity: 4.13%
# Sample Interval 95% CI: [17.1, 22.9] ms
#
# Session 22:
# Missing Samples: -0.00%
# Timestamp Continuity: 88.27%
# Sample Interval 95% CI: [16.4, 22.2] ms
#
# Session 23:
# Missing Samples: -0.00%
# Timestamp Continuity: 17.09%
# Sample Interval 95% CI: [17.0, 22.7] ms
#
# Session 24:
# Missing Samples: -0.00%
# Timestamp Continuity: 92.86%
# Sample Interval 95% CI: [15.9, 22.6] ms
#
# Session 25:
# Missing Samples: -0.00%
# Timestamp Continuity: 82.37%
# Sample Interval 95% CI: [15.2, 23.1] ms
#
# Session 26:
# Missing Samples: -0.00%
# Timestamp Continuity: 91.09%
# Sample Interval 95% CI: [16.2, 22.3] ms

# %%
# Information that cannot be derived from raw sensor data alone:
"""
The following metrics from your LaTeX document cannot be calculated from the raw sensor data alone:

1. Number of unique subjects (requires metadata)
2. Active eating duration and non-eating duration (requires activity labels)
3. Movement pattern analysis specific to eating gestures:
   - Mean acceleration peak during bites
   - Standard deviation of bite acceleration peak
   - Typical movement duration
   - Primary movement axis identification
4. Activity distribution (eating vs. non-eating periods)

These metrics would need to be calculated using additional data sources such as:
- Subject identification metadata
- Activity labels or annotations
- Eating gesture annotations
- Manual or automated bite detection results
"""
